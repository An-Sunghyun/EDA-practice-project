# %%
#Imports
import numpy as np # linear algebra
import pandas as pd # 데이터 전처리
import seaborn as sns # 시각화
import matplotlib.pyplot as plt # 시각화

#Seaborn theme
sns.set_theme(style="darkgrid")

# %%
#Read csv
df = pd.read_csv("online_store_customer_data.csv", index_col=0)
df.head()
# Out:
#                   Transaction_ID  Gender   Age Marital_status  State_names  \
# Transaction_date
# 1/1/2019                  151200  Female  19.0         Single       Kansas
# 1/1/2019                  151201    Male  49.0         Single     Illinois
# 1/1/2019                  151202    Male  63.0        Married   New Mexico
# 1/1/2019                  151203     NaN  18.0         Single     Virginia
# 1/1/2019                  151204    Male  27.0         Single  Connecticut
#
#                    Segment Employees_status Payment_method  Referal  \
# Transaction_date
# 1/1/2019             Basic     Unemployment          Other      1.0
# 1/1/2019             Basic    self-employed           Card      0.0
# 1/1/2019             Basic          workers         PayPal      1.0
# 1/1/2019          Platinum          workers           Card      1.0
# 1/1/2019             Basic    self-employed           Card      0.0
#
#                   Amount_spent
# Transaction_date
# 1/1/2019               2051.36
# 1/1/2019                544.04
# 1/1/2019               1572.60
# 1/1/2019               1199.79
# 1/1/2019                   NaN

# %%
# 결측치 제거
df.dropna(axis=0)
# Out:
#                   Transaction_ID  Gender   Age Marital_status     State_names  \
# Transaction_date
# 1/1/2019                  151200  Female  19.0         Single          Kansas
# 1/1/2019                  151201    Male  49.0         Single        Illinois
# 1/1/2019                  151202    Male  63.0        Married      New Mexico
# 1/3/2019                  151205    Male  71.0         Single          Hawaii
# 1/3/2019                  151206  Female  34.0        Married      New Mexico
# ...                          ...     ...   ...            ...             ...
# 4/30/2021                 153694    Male  34.0         Single         Florida
# 5/1/2021                  153695  Female  57.0         Single  South Carolina
# 5/1/2021                  153696  Female  36.0        Married          Hawaii
# 5/1/2021                  153697    Male  22.0         Single  South Carolina
# 5/1/2021                  153699    Male  48.0         Single      California
#
#                    Segment Employees_status Payment_method  Referal  \
# Transaction_date
# 1/1/2019             Basic     Unemployment          Other      1.0
# 1/1/2019             Basic    self-employed           Card      0.0
# 1/1/2019             Basic          workers         PayPal      1.0
# 1/3/2019             Basic        Employees         PayPal      1.0
# 1/3/2019          Platinum        Employees         PayPal      1.0
# ...                    ...              ...            ...      ...
# 4/30/2021          Missing        Employees          Other      1.0
# 5/1/2021          Platinum    self-employed           Card      0.0
# 5/1/2021            Silver    self-employed         PayPal      1.0
# 5/1/2021             Basic          workers         PayPal      1.0
# 5/1/2021            Silver          workers         PayPal      1.0
#
#                   Amount_spent
# Transaction_date
# 1/1/2019               2051.36
# 1/1/2019                544.04
# 1/1/2019               1572.60
# 1/3/2019               2922.66
# 1/3/2019               1481.42
# ...                        ...
# 4/30/2021               286.82
# 5/1/2021                150.10
# 5/1/2021                708.88
# 5/1/2021               2030.07
# 5/1/2021               1073.15
#
# [2044 rows x 10 columns]

# %%
# 성별로 그룹핑 후 전체 거래 횟수 시각화
df_by_gender = df.groupby("Gender").size().sort_values(ascending=False).reset_index()
plt.rcParams["figure.figsize"] = (5, 5)
ax = sns.barplot(x="Gender", y=0, data=df_by_gender, order=df_by_gender.Gender)
ax.set_xlabel("Total Transaction", fontsize=15)
ax.set_ylabel("")
ax.set_title("Total Transaction by Gender", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total Transaction by Gender')

# %%
# 혼인 여부로 그룹핑
df_by_martial = df.groupby("Marital_status").size().sort_values(ascending=False).reset_index()
plt.rcParams["figure.figsize"] = (5, 5)
ax = sns.barplot(x="Marital_status", y=0, data=df_by_martial, order=df_by_martial.Marital_status)
ax.set_xlabel("Total Transaction", fontsize=15)
ax.set_ylabel("")
ax.set_title("Total Transaction by Marital_status", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total Transaction by Marital_status')

# %%
# 지역으로 그룹핑
df_by_state = df.groupby("State_names").size().sort_values(ascending=False).reset_index()
plt.rcParams["figure.figsize"] = (60, 10)
ax = sns.barplot(x="State_names", y=0, data=df_by_state, order=df_by_state.State_names)
ax.set_xlabel("Total Transaction", fontsize=15)
ax.set_ylabel("")
ax.set_title("Total Transaction by State", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total Transaction by State')

# %%
# 멤버쉽 등급으로 그룹핑
df_by_segment = df.groupby("Segment").size().sort_values(ascending=False).reset_index()
plt.rcParams["figure.figsize"] = (60, 10)
ax = sns.barplot(x="Segment", y=0, data=df_by_segment, order=df_by_segment.Segment)
ax.set_xlabel("Total Transaction", fontsize=15)
ax.set_ylabel("")
ax.set_title("Total Transaction by Segment", fontsize=20)
