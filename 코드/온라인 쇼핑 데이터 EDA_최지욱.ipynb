# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("C:/Users/Jiuk Choi/Documents/python/online_store_customer_data.csv", index_col=0, engine='python')
#csv reading
fig = plt.figure(figsize=(20, 12)) # 차트 생성 및 사이즈 설정
ax = fig.add_subplot(1,1,1) #axis

ax.plot(df['Amount_spent'], label='df', color='b')

#dataset의 Amount_spent를 아무 생각 없이 그래프로 나타내어 봄.
#시간도 굉장히 오래 걸리고 알아볼 수 조차 없다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro') # 1st x, 2nd y, 3rd Format string
plt.axis([0, 6, 0, 20]) # Setting axis to set the range of min and max of x,y
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 200ms 간격으로 균일하게 샘플된 시간
t = np.arange(0., 5., 0.2) #numpy, sampling regularly time of 0.2 sec

# 빨간 대쉬, 파란 사각형, 녹색 삼각형
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
#               red --          blue square    green triangle
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([2, 3, 5, 10]) 
# Single list is recognized as y-values and x-values are automatically set as [1,2,3,4]
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# 1st value is x, 2nd is y. same as upper graph
plt.show()

# %%
import matplotlib.pyplot as plt

data_dict = {'data_x': [1, 2, 3, 4, 5], 'data_y': [2, 3, 5, 10, 8]}
# Setting data_x as a dictionary. data_x is a key, list [12345] is value.
plt.plot('data_x', 'data_y', data=data_dict) # Setting data parameter as data_dict
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-Label') # Setting x_value's label as X-Label
plt.ylabel('Y-Label') # Setting y_value's label as Y-Label
plt.show()

# %%
import matplotlib.pyplot as plt
#Padding(여백)

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15) # Setting x_value's label as X-Axis and pad 15
plt.ylabel('Y-Axis', labelpad=20) # Setting y_value's label as Y-Axis and pad 20
plt.show()

# %%
import matplotlib.pyplot as plt
# Setting font
font1 = {'family': 'serif',
        'color': 'b',
        'weight': 'bold',
        'size': 14
        }

font2 = {'family': 'fantasy',
        'color': 'deeppink',
        'weight': 'normal',
        'size': 'xx-large'
        }

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=20, fontdict=font2)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)') # x,y values labeled as Price
plt.xlabel('X-Axis') # Label
plt.ylabel('Y-Axis') # Label
plt.legend() #범례 표시 함수

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xlim([0, 5])      # X축의 범위: [xmin, xmax]
plt.ylim([0, 20])     # Y축의 범위: [ymin, ymax]

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0, 5, 0, 20])  # X, Y축의 범위: [xmin, xmax, ymin, ymax]
#axis() 함수에 [xmin, xmax, ymin, ymax]의 형태로 X, Y축의 범위를 지정
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.axis('square') #축의 길이 동일
plt.axis('scaled')  #축의 길이가 동일 비율로(스케일) 조정


plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

x_range, y_range = plt.xlim(), plt.ylim()
print(x_range, y_range)

axis_range = plt.axis('square')
print(axis_range)

plt.show()
# Out:
# (0.85, 4.15) (1.6, 10.4)
# (0.85, 9.65, 1.6, 10.4)

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], '-', color='C0', label='Solid') #단단한(solid) 선
plt.plot([1, 2, 3], [3, 3, 3], '--', color='C0', label='Dashed')#Dash 여러개
plt.plot([1, 2, 3], [2, 2, 2], ':', color='C0', label='Dotted') #Dot...점선
plt.plot([1, 2, 3], [1, 1, 1], '-.', color='C0', label='Dash-dot')# -.Dash & Dot
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4) #location = 우상단 ncol에 4개
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
#        X_value    Y_value    Line style         color       label
plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.tight_layout() #대충 padding을 딱 붙여 주는 듯.
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo') # blue + o (circle)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
import matplotlib.pyplot as plt

# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-')    # blue + o (circle) + solid
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')     # blue + o (circle) + dash
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([4, 5, 6], marker="H",linestyle='dotted') #line, label 등 추가 가능
plt.plot([3, 4, 5], marker="d")
plt.plot([2, 3, 4], marker="x")
plt.plot([1, 2, 3], marker=11)
plt.plot([0, 1, 2], marker='$Z$')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], 'r--')
plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], 'g:')
plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], 'b')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4] #미리 초기화 및 선언 해두고 plot()함수로 갖다 쓰기
y = [2, 3, 5, 10]

plt.plot(x, y) 
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[1:3], y[1:3], alpha=0.5) #채운다_사이(x[1], y[1]),(x[2],y[2])

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_betweenx(y[2:4], x[2:4], alpha=0.5)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10, 10, 100) #Start at -10, Stop at 10, num is 100
y = x ** 3

plt.plot(x, y)
plt.xscale('symlog') #symmetrical log

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 5, 100) #Start at 0, Stop at 5, num is 100
y = np.exp(x)

plt.plot(x, y)
# plt.yscale('linear')
plt.yscale('log')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2) #0에서, 2까지, 0.2 간격으로
# [ 0. 0.2 0.4 0.6 0.8 1. 1.2 1.4 1.6 1.8]

plt.plot(x, x, 'r--', x, x**2, 'bo', x, x**3, 'g-.')
#       x 값, y 값, 스타일 * 3
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(True) #그냥 TRUE만 하면 그리드 표시됨. 쉽다.

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.xticks([0, 1, 2]) #xticks 함수로 x축의 눈금 정함
plt.yticks(np.arange(1, 6)) #yticks 함수로 y축의 눈금 정함

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# 기본 csv 파일 불러오기
# df = pd.read_csv("C:/Bigdata/work/Project01/online_store_customer_data.csv")

# Gender를 인덱스 칼럼으로 하여 불러오기
df = pd.read_csv("C:/Users/Jiuk Choi/Documents/python/online_store_customer_data.csv", index_col='Gender')

df.describe()
# Out:
#        Transaction_ID          Age      Referal  Amount_spent
# count     2512.000000  2470.000000  2357.000000   2270.000000
# mean    152443.931131    46.637652     0.652100   1418.422577
# std        724.580482    18.186277     0.476405    878.507451
# min     151200.000000    15.000000     0.000000      2.090000
# 25%     151815.750000    32.000000     0.000000    678.192500
# 50%     152443.500000    47.000000     1.000000   1341.435000
# 75%     153071.250000    62.000000     1.000000   2038.102500
# max     153699.000000    78.000000     1.000000   2999.980000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

age_sp = df.groupby('Age')['Amount_spent'].mean()
#나이당-쓴 돈.평균()

age_sp
# Out:
# Age
# 15.0    1533.035405
# 16.0    1413.052558
# 17.0    1161.580968
# 18.0    1707.077143
# 19.0    1555.736667
#            ...
# 74.0    1078.958000
# 75.0    1460.041395
# 76.0    1418.097333
# 77.0    1304.313824
# 78.0    1430.301250
# Name: Amount_spent, Length: 63, dtype: float64

# %%
sb.barplot(x='Age', y='Amount_spent', data = df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Amount_spent'>

# %%
h = df.hist(figsize=(30,20)) 
#히스토그램을 통한 분포 확인

# %%
sex_df = df.loc['Male']
# 인덱스가 Male인 인자들만 보기
sex_df
# Out:
#        Transaction_date  Transaction_ID   Age Marital_status     State_names  \
# Gender
# Male           1/1/2019          151201  49.0         Single        Illinois
# Male           1/1/2019          151202  63.0        Married      New Mexico
# Male           1/1/2019          151204  27.0         Single     Connecticut
# Male           1/3/2019          151205  71.0         Single          Hawaii
# Male           1/3/2019          151207  37.0        Married     Connecticut
# ...                 ...             ...   ...            ...             ...
# Male          4/30/2021          153692  34.0        Married         Wyoming
# Male          4/30/2021          153693  54.0        Married         Alabama
# Male          4/30/2021          153694  34.0         Single         Florida
# Male           5/1/2021          153697  22.0         Single  South Carolina
# Male           5/1/2021          153699  48.0         Single      California
#
#         Segment Employees_status Payment_method  Referal  Amount_spent
# Gender
# Male      Basic    self-employed           Card      0.0        544.04
# Male      Basic          workers         PayPal      1.0       1572.60
# Male      Basic    self-employed           Card      0.0           NaN
# Male      Basic        Employees         PayPal      1.0       2922.66
# Male      Basic          workers         PayPal      1.0       1149.55
# ...         ...              ...            ...      ...           ...
# Male      Basic    self-employed          Other      1.0       1691.57
# Male      Basic        Employees           Card      0.0        266.61
# Male    Missing        Employees          Other      1.0        286.82
# Male      Basic          workers         PayPal      1.0       2030.07
# Male     Silver          workers         PayPal      1.0       1073.15
#
# [1128 rows x 10 columns]

# %%
df
# Out:
#        Transaction_date  Transaction_ID   Age Marital_status     State_names  \
# Gender
# Female         1/1/2019          151200  19.0         Single          Kansas
# Male           1/1/2019          151201  49.0         Single        Illinois
# Male           1/1/2019          151202  63.0        Married      New Mexico
# NaN            1/1/2019          151203  18.0         Single        Virginia
# Male           1/1/2019          151204  27.0         Single     Connecticut
# ...                 ...             ...   ...            ...             ...
# Female         5/1/2021          153695  57.0         Single  South Carolina
# Female         5/1/2021          153696  36.0        Married          Hawaii
# Male           5/1/2021          153697  22.0         Single  South Carolina
# NaN            5/1/2021          153698  44.0         Single        New York
# Male           5/1/2021          153699  48.0         Single      California
#
#          Segment Employees_status Payment_method  Referal  Amount_spent
# Gender
# Female     Basic     Unemployment          Other      1.0       2051.36
# Male       Basic    self-employed           Card      0.0        544.04
# Male       Basic          workers         PayPal      1.0       1572.60
# NaN     Platinum          workers           Card      1.0       1199.79
# Male       Basic    self-employed           Card      0.0           NaN
# ...          ...              ...            ...      ...           ...
# Female  Platinum    self-employed           Card      0.0        150.10
# Female    Silver    self-employed         PayPal      1.0        708.88
# Male       Basic          workers         PayPal      1.0       2030.07
# NaN        Basic        Employees         PayPal      0.0       1909.77
# Male      Silver          workers         PayPal      1.0       1073.15
#
# [2512 rows x 10 columns]

# %%
st_df = pd.read_csv("C:/Users/Jiuk Choi/Documents/python/online_store_customer_data.csv", index_col='State_names')
#거주중인 주의 이름을 인덱스로 하는 데이터프레임 st_df를  csv read 해서 생성
state_df = st_df.loc[['Kansas','Illinois']]
#label_location을 캔자스 및 일리노이 주로 설정
state_df
# Out:
#             Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# State_names
# Kansas              1/1/2019          151200  Female  19.0         Single
# Kansas             1/26/2019          151260    Male  55.0        Married
# Kansas             1/26/2019          151260    Male  55.0        Married
# Kansas              2/6/2019          151295  Female  22.0        Married
# Kansas             2/12/2019          151314  Female  55.0        Married
# ...                      ...             ...     ...   ...            ...
# Illinois            3/1/2021          153510  Female  76.0        Married
# Illinois            3/5/2021          153521  Female  45.0         Single
# Illinois            3/7/2021          153526    Male  35.0         Single
# Illinois           3/26/2021          153591  Female  15.0        Married
# Illinois           4/26/2021          153678  Female  50.0        Married
#
#               Segment Employees_status Payment_method  Referal  Amount_spent
# State_names
# Kansas          Basic     Unemployment          Other      1.0       2051.36
# Kansas          Basic        Employees          Other      1.0       1277.64
# Kansas          Basic        Employees          Other      1.0       1277.64
# Kansas        Missing          workers           Card      0.0       2061.14
# Kansas       Platinum        Employees         PayPal      1.0        329.18
# ...               ...              ...            ...      ...           ...
# Illinois        Basic    self-employed         PayPal      1.0        631.89
# Illinois     Platinum          workers           Card      1.0       1813.16
# Illinois        Basic        Employees          Other      0.0         74.37
# Illinois        Basic        Employees          Other      0.0       2643.85
# Illinois       Silver    self-employed         PayPal      1.0       1453.75
#
# [108 rows x 10 columns]

# %%
sb.barplot(x='Employees_status', y='Amount_spent', data = st_df)



#캔자스 주와 일리노이 주에 사는 고객들의 고용 형태에 따른 사용 금액

#백수(Unemployment)와 노동자(workers) 에 비해 고용인 및 자영업자의 사용 금액이 근소하게 높으며,
#백수의 소비 금액이 가장 적음.
# Out:
# <AxesSubplot:xlabel='Employees_status', ylabel='Amount_spent'>

# %%
ax = state_df.plot(kind='bar', title='', figsize=(12, 4), legend=True, fontsize=12)
# ax = 바 형태, 타이틀은 캔,일리 , 범례 True
ax.set_xlabel('State_names', fontsize=12) # X축 정보: 주 이름
ax.set_ylabel('Amount_spent', fontsize=12)# Y축 정보: 사용한 금액
ax.legend(['Kansas', 'Illinois'], fontsize=12)
#근데 이상하게 나옴...

# %%
ax = st_df.plot(kind='bar', title='', figsize=(12, 4), legend=True, fontsize=12)
# ax = 바 형태, 타이틀은 캔,일리 , 범례 True
ax.set_xlabel('Employees_status', fontsize=12) # X축 정보: 고용 형태
ax.set_ylabel('Amount_spent.mean()', fontsize=12)# Y축 정보: 사용한 금액

#모든 Amount_spent를 출력하며 하단에 Employee_status label만 붙여 주는 듯...
# Out:
# Text(0, 0.5, 'Amount_spent.mean()')

# %%
em_df = pd.read_csv("C:/Bigdata/work/Project01/online_store_customer_data.csv", index_col='Employees_status')
#고용 형태를 인덱스로 하는 데이터프레임 em_df를  csv read 해서 생성

# State나 Age를 기반으로 가격을 시각화 하는 것은 State와 가격의 가짓수가 너무 많아 어려움.

# 그래서 Kansas와 Illinois 주 만을 loc하는 State_df를 사용했으나 같은 인덱스를 두번 사용할 수는 없는듯?
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\OTAKUK~1\AppData\Local\Temp/ipykernel_19132/628665835.py in <module>
# ----> 1 em_df = pd.read_csv("C:/Bigdata/work/Project01/online_store_customer_data.csv", index_col='Employees_status')
#       2 #고용 형태를 인덱스로 하는 데이터프레임 em_df를  csv read 해서 생성
#       3
#       4 # State나 Age를 기반으로 가격을 시각화 하는 것은 State와 가격의 가짓수가 너무 많아 어려움.
#       5
#
# c:\Anaconda\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Anaconda\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     678     kwds.update(kwds_defaults)
#     679
# --> 680     return _read(filepath_or_buffer, kwds)
#     681
#     682
#
# c:\Anaconda\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# c:\Anaconda\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     931
#     932         self.handles: IOHandles | None = None
# --> 933         self._engine = self._make_engine(f, self.engine)
#     934
#     935     def close(self):
#
# c:\Anaconda\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1215             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217             self.handles = get_handle(  # type: ignore[call-overload]
#    1218                 f,
#    1219                 mode,
#
# c:\Anaconda\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     787         if ioargs.encoding and "b" not in ioargs.mode:
#     788             # Encoding
# --> 789             handle = open(
#     790                 handle,
#     791                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Bigdata/work/Project01/online_store_customer_data.csv'

# %%
sb.barplot(x='Gender', y='Amount_spent', data = em_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\OTAKUK~1\AppData\Local\Temp/ipykernel_19132/3564409682.py in <module>
# ----> 1 sb.barplot(x='Gender', y='Amount_spent', data = em_df)
#
# NameError: name 'em_df' is not defined

# %%
sb.barplot(x='Segment', y='Amount_spent', data = em_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\OTAKUK~1\AppData\Local\Temp/ipykernel_19132/3644417043.py in <module>
# ----> 1 sb.barplot(x='Segment', y='Amount_spent', data = em_df)
#
# NameError: name 'em_df' is not defined

# %%
# seaborn Barplot 말고 그냥 Matplotlib의 plot 이용.
g = df.groupby(["State_names"])["Amount_spent"].mean()
# g = df를 [(주 이름)과 (사용 금액) 으로 묶음].평균()
g.plot(kind = "bar")
# plot(종류 = "바")

#조금 촘촘해서 알아보기 어렵지만 Bar plot에 비해 얇고 세워져 있어 구별 가능함
# Out:
# <AxesSubplot:xlabel='State_names'>

# %%
g.plot.bar(figsize = (15,5))
#사이즈를 키우니 확실히 시인성이 향상
# Out:
# <AxesSubplot:xlabel='State_names'>

# %%
g = df.groupby(["State_names"])["Amount_spent"].mean().sort_values(ascending = False)
# g = df를 [(주 이름)과 (사용 금액) 으로 묶음].평균().값으로_정렬(오름차순 = 아니오)
g.plot.bar(figsize = (15,5))
# Out:
# <AxesSubplot:xlabel='State_names'>

# %%
g = df.groupby(["State_names"])["Amount_spent"].mean().sort_values(ascending = True)
# g = df를 [(주 이름)과 (사용 금액) 으로 묶음].평균().값으로_정렬(오름차순 = 예)
g.plot.bar(figsize = (15,5))
#종류가 다양한 자료를 시각화 할 때엔 seaborn 보다는 matplot이 좋은 듯 함.
#https://seoyuun22.tistory.com/entry/Python-%EB%8D%B0%EC%9D%B4%ED%84%B0-%EC%8B%9C%EA%B0%81%ED%99%94-plotbarplot-boxplot-matplotlib-plot-%ED%95%9C%EA%B8%80-%EC%84%A4%EC%A0%95
# Out:
# <AxesSubplot:xlabel='State_names'>

# %%
g = df.groupby(["State_names"])["Amount_spent"].mean().sort_values(ascending = True)
# g = df를 [(주 이름)과 (사용 금액) 으로 묶음].평균().값으로_정렬(오름차순 = 예)
g.plot.barh(figsize = (5,15))
# Out:
# <AxesSubplot:ylabel='State_names'>

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2512 entries, Female to Male
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   object
#  1   Transaction_ID    2512 non-null   int64
#  2   Age               2470 non-null   float64
#  3   Marital_status    2512 non-null   object
#  4   State_names       2512 non-null   object
#  5   Segment           2512 non-null   object
#  6   Employees_status  2486 non-null   object
#  7   Payment_method    2512 non-null   object
#  8   Referal           2357 non-null   float64
#  9   Amount_spent      2270 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 280.4+ KB
#        Transaction_date  Transaction_ID   Age Marital_status  State_names  \
# Gender
# Female         1/1/2019          151200  19.0         Single       Kansas
# Male           1/1/2019          151201  49.0         Single     Illinois
# Male           1/1/2019          151202  63.0        Married   New Mexico
# NaN            1/1/2019          151203  18.0         Single     Virginia
# Male           1/1/2019          151204  27.0         Single  Connecticut
#
#          Segment Employees_status Payment_method  Referal  Amount_spent
# Gender
# Female     Basic     Unemployment          Other      1.0       2051.36
# Male       Basic    self-employed           Card      0.0        544.04
# Male       Basic          workers         PayPal      1.0       1572.60
# NaN     Platinum          workers           Card      1.0       1199.79
# Male       Basic    self-employed           Card      0.0           NaN

# %%
g.plot(kind='barh', stacked=True, title='day and size columns')
#df를 [(주 이름)과 (사용 금액) 으로 묶은 자료 g를 수평 바 형식으로 스택 구현
#하려 했으나, 사용 금액에는 수치만 존재하여 스택 구현하지 못함.
# Out:
# <AxesSubplot:title={'center':'day and size columns'}, ylabel='State_names'>

# %%
k = df.groupby(["Marital_status"])["Amount_spent"].mean().sort_values(stacked=True, ascending = True)
#기혼 여부와 사용 금액을 짝지어 나타내어 보려 했으나 왜인지 모르게 Stacked를 인식하지 못함
#stacked를 제거하니 Single한줄, Married한줄이라 stack될만한 자료가 없음.
k.plot.barh(figsize = (5,15))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\OTAKUK~1\AppData\Local\Temp/ipykernel_19132/2701566335.py in <module>
# ----> 1 k = df.groupby(["Marital_status"])["Amount_spent"].mean().sort_values(stacked=True, ascending = True)
#       2 #기혼 여부와 사용 금액을 짝지어 나타내어 보려 했으나 왜인지 모르게 Stacked를 인식하지 못함
#       3 #stacked를 제거하니 Single한줄, Married한줄이라 stack될만한 자료가 없음.
#       4 k.plot.barh(figsize = (5,15))
#
# c:\Anaconda\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: sort_values() got an unexpected keyword argument 'stacked'

# %%
df['State_names'].unique() # 주 이름만 모아 유니크한 이름 표시
df['Marital_status'].unique() # 기혼 여부의 유니크한 이름 표시
# Out:
# array(['Single', 'Married'], dtype=object)

# %%
df_tab = pd.crosstab(df['State_names'],df['Marital_status'])
#주 이름과 기혼 여부를 통합한 dataframe df_tab 생성

# %%
df_tab
# Out:
# Marital_status  Married  Single
# State_names
# Alabama              31      11
# Alaska               25      16
# Arizona              29      27
# Arkansas             28      27
# California           34      21
# Colorado             27      25
# Connecticut          20      32
# Delaware             36      20
# Florida              31      22
# Georgia              36      28
# Hawaii               25      21
# Idaho                28      17
# Illinois             33      34
# Indiana              28      15
# Iowa                 36      15
# Kansas               22      19
# Kentucky             31      28
# Louisiana            29      20
# Maine                40      22
# Maryland             29      16
# Massachusetts        31      32
# Michigan             26      26
# Minnesota            32      27
# Mississippi          28      16
# Missouri             33      24
# Montana              30      18
# Nebraska             23      18
# Nevada               36      19
# New Hampshire        29      14
# New Jersey           30      23
# New Mexico           39      16
# New York             29      26
# North Carolina       18      28
# North Dakota         30      11
# Ohio                 28      15
# Oklahoma             24      20
# Oregon               25      28
# Pennsylvania         34      18
# Rhode Island         34      17
# South Carolina       27      18
# South Dakota         31      21
# Tennessee            27      12
# Texas                27      22
# Utah                 25      18
# Vermont              30      24
# Virginia             28      18
# Washington           31      21
# West Virginia        30      24
# Wisconsin            32      13
# Wyoming              28      16

# %%
df_tab.plot(kind='barh', stacked=True, title='Customer Gender ratio of States',figsize = (5,15))
#주 이름과 기혼 여부를 통합한 dataframe df_tab을 Horizontal bar 형식으로 구현
#Stack 형식으로 구현하기 위해 주 이름당 기혼 여부(기혼/미혼)을 나누고, 이를 범례에 표시
plt.legend(loc='upper right')
#범례를 우측 상단으로

# %%
df_tab.plot(kind='bar', stacked=True, title='Customer Gender ratio of States',figsize = (15,5))
#주 이름과 기혼 여부를 통합한 dataframe df_tab을 bar 형식으로 표현
#Stack 형식으로 표현하기 위해 주 이름당 기혼 여부(기혼/미혼)을 나누고, 이를 범례에 표시
plt.legend(loc='upper right')
#범례를 우측 상단으로

# %%
g.plot(kind='pie')
#파이 형식의 차트를 생성하기 위해 kind=pie 이용.
# Out:
# <AxesSubplot:ylabel='Amount_spent'>

# %%
p = df.groupby(["Segment"])["Amount_spent"].sum()
#Segment와 사용 금액을 모두 더해 등급별 사용 금액 파이 차트로 구현
p.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Amount_spent'>

# %%
p = df.groupby(["Segment"])["Amount_spent"].sum()
#plt.pie 함수를 통해 구현된 파이차트의 세부 사항 변경
plt.pie(p, shadow = True, autopct= '%.1f%%')
#       데이터프레임 p를 목표로, 그림자, 퍼센티지 표시(0.1%까지)
plt.legend(loc = (1, 0.5))

p.plot(kind='pie')
# Out:
# No handles with labels found to put in legend.
# <AxesSubplot:ylabel='Amount_spent'>

# %%
df['Segment']
p
# Out:
# Segment
# Basic       1468199.39
# Gold         305695.99
# Missing      261264.82
# Platinum     573316.78
# Silver       611342.27
# Name: Amount_spent, dtype: float64
